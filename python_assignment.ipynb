# %%
"""
    Q1:- python was first developed by Guido Van Rossum, python was introduced in 1989 but was officially made available
        to public in feb 20th 1999.
        
   Q2:- python is an interpreted and dynamically type programming language which supports object oriented, structured and
        functional programming.
        
   Q3:- yes python is case sensitive when dealing with identifiers, the identifier is case sensitive so, "foo" and "FOO" are two
        different variables.
        
   Q4:- the correct extension of python file is .py .
   
   Q5:- python code is first compiled and then interpreted, therefore python is 'COMPILED INTERPRETED' language.
   
   Q6:- a code block is a group of statements that will be run as a unit. unlike other languages python uses indentation to define
        a block of code. this makes python unique among all programming languages. the indentation in python is done by whitespace.
        
   Q7:- # character is used before the line to give single line comment in python.
   
   Q8:- just open ur terminal and write a command
         python -V or python --version  
        and u will get to know the latest version of python u are currently working on.
        
   Q9:- python supports the creation of anonymous functions at runtime, using a construct called lambda.
        
   Q10:- pip stands for preferred installer program in python.
   
   Q11:- few built in funcn in python are:- 
         
         list()
         len()
         range()
         input()
         print()
         type()
         
    Q12:- the maximum possible length of an identifier is infinite, however to do so is not recommended.
    
    Q13:- the benefits of using python are listed as below:-
    
          a) it's simple and easy to learn.
          b) high level programming language.
          c) platform independent i.e, write once and run anywhere.
          d) portable.
          e) have a support of extensive libraries.
          
    Q14:- Python memory management is been divided into two parts. Methods and variables are created in Stack memory.
          Objects and instance variables values are created in Heap memory. 
          In stack memory - a stack frame is created whenever methods and variables are created.
          These stacks frames are destroyed automaticaly whenever functions/methods returns.
          
    Q15:- search python on browser and click the python for windows download option,
          after downloading click on the downloaded file and then u will see install python pop up,
          then click on install launcher option and add to path option then click install now and u are now good to go with python.
          
    Q16:- yes indentation is required in python. 
                                                  """
